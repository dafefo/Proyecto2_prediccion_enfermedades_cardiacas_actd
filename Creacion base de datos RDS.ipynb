# %%
sql_script = """
CREATE TABLE datacardiaca(
    age_group char(20),
    sex INT,
    cp INT,
    trestbps_group char(50),
    chol_group char(30),
    fbs INT,
    restecg INT,
    exang INT,
    slope INT,
    ca INT,
    thal INT,
    cardiac boolean
);
"""

# %%
sql_script += 'INSERT INTO datacardiaca (age_group, sex, cp, trestbps_group, chol_group, fbs, restecg, exang, slope, ca, thal, cardiac) VALUES\n'

# %%
import pandas as pd
df = pd.read_csv("C:/Users/dafef/OneDrive - Universidad de los Andes/Decimo Semestre/Analitica computacional/datoscat.csv")
print(df.head())
# Out:
#   age_group  sex  cp         trestbps_group chol_group  fbs  restecg  exang  \
# 0     Mayor    1   1  presionarterialnivel2       alto    1        2      0
# 1     Mayor    1   4  presionarterialnivel2    muyalto    0        2      1
# 2     Mayor    1   4                elevada       alto    0        2      1
# 3     Joven    1   3  presionarterialnivel1    muyalto    0        0      0
# 4     Joven    0   2  presionarterialnivel1       alto    0        2      0
#
#    slope  ca  thal  cardiac
# 0      3   0     6    False
# 1      2   3     3     True
# 2      2   2     7     True
# 3      3   0     3    False
# 4      1   0     3    False

# %%
values = []

for i, row in df.iterrows():
    value = f"({row['age_group']},{int(row['sex'])},{row['cp']},{row['trestbps_group']},{row['chol_group']},{int(row['fbs'])},{int(row['restecg'])},{int(row['exang'])},{int(row['slope'])},{int(row['ca'])},{int(row['thal'])},{row['cardiac']})"
    print(value)
    values.append(value)


sql_script += ',\n'.join(values)+';'
print(len(values))
# Out:
# (Mayor,1,1,presionarterialnivel2,alto,1,2,0,3,0,6,False)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,1,2,3,3,True)
# (Mayor,1,4,elevada,alto,0,2,1,2,2,7,True)
# (Joven,1,3,presionarterialnivel1,muyalto,0,0,0,3,0,3,False)
# (Joven,0,2,presionarterialnivel1,alto,0,2,0,1,0,3,False)
# (Mayor,1,2,elevada,alto,0,0,0,1,0,3,False)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,2,0,3,2,3,True)
# (Mayor,0,4,elevada,muyalto,0,0,1,1,0,3,False)
# (Mayor,1,4,presionarterialnivel1,muyalto,0,2,0,2,1,7,True)
# (Mayor,1,4,presionarterialnivel2,alto,1,2,1,3,0,7,True)
# (Mayor,1,4,presionarterialnivel2,normal,0,0,0,2,0,6,False)
# (Mayor,0,2,presionarterialnivel2,muyalto,0,2,0,2,0,3,False)
# (Mayor,1,3,presionarterialnivel1,muyalto,1,2,1,2,1,6,True)
# (Joven,1,2,elevada,muyalto,0,0,0,1,0,7,False)
# (Mayor,1,3,presionarterialnivel2,normal,1,0,0,1,0,7,False)
# (Mayor,1,3,presionarterialnivel2,normal,0,0,0,1,0,3,False)
# (Joven,1,2,normal,alto,0,0,0,3,0,7,True)
# (Mayor,1,4,presionarterialnivel2,alto,0,0,0,1,0,3,False)
# (Joven,0,3,presionarterialnivel1,muyalto,0,0,0,1,0,3,False)
# (Joven,1,2,presionarterialnivel1,muyalto,0,0,0,1,0,3,False)
# (Mayor,1,1,normal,alto,0,2,1,2,0,3,False)
# (Mayor,0,1,presionarterialnivel2,muyalto,1,2,0,1,0,3,False)
# (Mayor,1,2,elevada,muyalto,0,2,0,2,0,3,True)
# (Mayor,1,3,presionarterialnivel1,alto,0,2,0,1,2,7,True)
# (Mayor,1,4,presionarterialnivel1,alto,0,2,1,2,2,7,True)
# (Joven,0,3,elevada,alto,0,0,0,2,0,3,False)
# (Mayor,0,3,elevada,muyalto,0,0,0,1,0,3,False)
# (Mayor,0,1,presionarterialnivel2,alto,0,0,0,3,0,3,False)
# (Joven,1,4,presionarterialnivel2,muyalto,0,0,0,1,0,3,False)
# (Joven,1,4,normal,normal,0,2,1,2,0,7,True)
# (Mayor,0,1,presionarterialnivel2,alto,0,0,0,1,2,3,False)
# (Mayor,1,4,normal,alto,1,0,1,1,2,7,True)
# (Mayor,1,3,presionarterialnivel2,muyalto,0,0,0,1,0,3,True)
# (Mayor,1,4,presionarterialnivel1,alto,0,0,0,2,0,7,False)
# (Joven,1,3,presionarterialnivel1,alto,0,0,1,1,0,3,False)
# (Joven,1,4,presionarterialnivel2,alto,0,0,0,1,0,3,False)
# (Joven,1,4,elevada,normal,0,2,1,2,0,7,True)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,1,2,1,6,True)
# (Mayor,1,4,presionarterialnivel1,muyalto,0,0,1,2,1,7,True)
# (Mayor,1,3,presionarterialnivel2,muyalto,1,0,1,2,0,3,False)
# (Mayor,0,4,presionarterialnivel2,alto,0,2,0,2,3,7,True)
# (Joven,1,1,presionarterialnivel2,normal,0,0,1,1,0,7,False)
# (Mayor,0,2,presionarterialnivel2,muyalto,0,0,0,1,2,3,False)
# (Mayor,1,3,presionarterialnivel2,alto,1,0,0,1,0,3,False)
# (Mayor,0,4,presionarterialnivel1,muyalto,0,2,0,1,0,3,True)
# (Mayor,1,3,normal,alto,0,2,0,2,1,7,True)
# (Mayor,1,3,normal,normal,0,0,0,1,0,3,False)
# (Joven,1,4,presionarterialnivel2,muyalto,0,2,0,2,0,7,True)
# (Mayor,0,3,presionarterialnivel2,muyalto,1,2,0,1,1,3,False)
# (Mayor,1,3,presionarterialnivel1,normal,1,2,0,3,0,3,False)
# (Joven,0,2,normal,normal,0,0,0,1,1,3,False)
# (Mayor,1,4,elevada,normal,0,0,0,1,0,7,False)
# (Joven,1,4,normal,muyalto,0,2,0,1,1,3,True)
# (Joven,1,2,presionarterialnivel1,alto,0,2,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel1,muyalto,0,0,1,1,1,7,True)
# (Mayor,1,4,elevada,muyalto,0,2,1,2,1,7,True)
# (Joven,1,3,presionarterialnivel2,alto,0,0,0,2,1,7,True)
# (Joven,1,4,normal,normal,0,2,0,1,0,7,True)
# (Mayor,1,3,elevada,muyalto,0,2,0,3,1,3,False)
# (Mayor,1,1,elevada,alto,0,2,1,1,1,3,False)
# (Mayor,0,4,presionarterialnivel1,muyalto,0,0,1,2,0,7,True)
# (Joven,0,3,presionarterialnivel2,normal,0,2,1,3,0,3,False)
# (Mayor,1,4,elevada,alto,0,2,1,2,3,7,True)
# (Mayor,0,3,presionarterialnivel1,muyalto,1,0,0,1,0,3,False)
# (Mayor,1,4,elevada,normal,0,0,0,2,1,7,True)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,1,2,2,7,True)
# (Mayor,1,3,presionarterialnivel2,normal,0,2,0,2,0,3,True)
# (Mayor,1,3,presionarterialnivel2,alto,0,2,0,1,0,7,False)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,1,3,0,7,True)
# (Joven,1,3,presionarterialnivel2,alto,0,0,0,2,0,3,True)
# (Mayor,0,3,presionarterialnivel2,muyalto,0,0,0,1,0,3,False)
# (Mayor,1,4,elevada,muyalto,1,0,0,2,2,7,True)
# (Mayor,1,4,elevada,muyalto,0,0,1,2,2,7,True)
# (Mayor,1,4,normal,muyalto,0,2,0,1,2,6,True)
# (Joven,1,4,normal,normal,0,2,0,1,1,3,True)
# (Mayor,0,3,presionarterialnivel2,muyalto,0,2,0,1,0,3,False)
# (Mayor,1,4,elevada,muyalto,0,2,1,2,1,7,True)
# (Mayor,0,3,presionarterialnivel2,muyalto,0,2,0,1,1,3,False)
# (Joven,1,2,presionarterialnivel1,muyalto,0,2,0,2,0,3,False)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,1,1,0,7,True)
# (Joven,1,4,normal,alto,0,2,1,2,0,3,False)
# (Mayor,0,4,presionarterialnivel1,muyalto,0,2,0,2,0,3,False)
# (Joven,1,3,presionarterialnivel2,muyalto,0,2,0,1,0,3,False)
# (Mayor,1,3,crisis,muyalto,1,2,1,2,0,7,True)
# (Mayor,1,2,elevada,muyalto,0,0,0,1,0,3,False)
# (Joven,1,3,presionarterialnivel2,alto,0,2,0,1,0,3,False)
# (Joven,1,3,presionarterialnivel1,muyalto,0,2,0,1,0,3,False)
# (Mayor,0,4,presionarterialnivel1,alto,0,2,0,1,0,3,False)
# (Mayor,0,3,presionarterialnivel1,muyalto,0,2,0,1,0,3,False)
# (Mayor,1,4,elevada,muyalto,0,2,0,2,0,3,False)
# (Mayor,0,4,presionarterialnivel2,normal,0,2,0,3,3,7,True)
# (Mayor,1,3,presionarterialnivel1,alto,0,0,0,2,3,7,False)
# (Joven,0,3,normal,normal,0,0,0,2,0,3,False)
# (Mayor,0,3,presionarterialnivel1,muyalto,0,2,0,1,0,3,False)
# (Mayor,1,4,elevada,muyalto,0,0,1,1,1,7,True)
# (Mayor,1,4,normal,alto,0,2,1,2,1,7,True)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,2,0,2,2,7,True)
# (Mayor,1,2,presionarterialnivel1,alto,0,0,0,1,1,3,False)
# (Joven,1,4,elevada,alto,0,2,0,1,0,3,False)
# (Joven,1,4,normal,muyalto,0,2,0,1,0,3,False)
# (Joven,1,1,normal,normal,0,2,0,1,0,3,False)
# (Mayor,0,4,elevada,muyalto,0,2,0,1,1,3,False)
# (Mayor,0,3,normal,muyalto,1,2,0,1,1,3,False)
# (Joven,1,3,elevada,normal,0,0,0,2,3,7,True)
# (Mayor,1,2,normal,muyalto,0,0,0,1,0,7,False)
# (Mayor,1,4,presionarterialnivel2,normal,0,0,1,1,1,7,True)
# (Mayor,1,3,elevada,alto,0,2,0,2,1,7,True)
# (Mayor,1,4,elevada,muyalto,0,0,1,2,1,7,True)
# (Joven,1,4,normal,alto,0,0,0,2,0,7,True)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,2,1,2,0,7,True)
# (Mayor,1,4,elevada,muyalto,1,2,1,2,1,3,True)
# (Mayor,1,1,normal,normal,0,2,0,2,0,6,False)
# (Joven,0,4,presionarterialnivel1,muyalto,1,2,1,2,0,7,True)
# (Mayor,0,3,presionarterialnivel1,muyalto,0,0,0,2,1,7,True)
# (Joven,1,2,presionarterialnivel1,alto,0,0,0,2,0,6,False)
# (Mayor,1,3,presionarterialnivel2,alto,1,2,0,1,0,3,False)
# (Joven,0,4,presionarterialnivel1,normal,0,0,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel1,muyalto,1,2,1,1,3,7,True)
# (Mayor,1,4,presionarterialnivel1,muyalto,0,2,0,2,1,7,True)
# (Joven,1,4,presionarterialnivel1,muyalto,1,2,1,1,2,7,True)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,2,0,2,3,7,True)
# (Mayor,1,3,normal,alto,0,0,1,2,0,3,False)
# (Mayor,1,4,presionarterialnivel2,alto,0,0,1,3,0,7,True)
# (Mayor,1,1,presionarterialnivel1,muyalto,1,2,0,2,1,3,True)
# (Joven,0,2,presionarterialnivel1,alto,0,2,0,2,0,3,False)
# (Mayor,0,4,crisis,muyalto,1,2,1,3,2,7,True)
# (Mayor,1,4,normal,alto,0,0,1,2,1,7,True)
# (Joven,1,2,elevada,alto,0,0,0,1,0,3,False)
# (Mayor,0,4,elevada,alto,0,0,0,1,0,3,False)
# (Mayor,1,3,elevada,muyalto,0,2,0,2,0,7,False)
# (Mayor,1,3,normal,alto,0,0,1,1,1,7,False)
# (Joven,1,2,presionarterialnivel1,alto,0,2,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,1,1,0,3,False)
# (Joven,0,3,elevada,alto,0,0,0,2,0,3,False)
# (Mayor,0,2,presionarterialnivel1,muyalto,0,2,0,2,0,3,False)
# (Mayor,1,4,presionarterialnivel2,normal,0,0,1,3,0,7,True)
# (Mayor,1,2,elevada,muyalto,0,2,0,2,1,7,True)
# (Joven,1,4,elevada,normal,0,0,1,2,0,7,True)
# (Mayor,1,3,elevada,muyalto,1,2,0,2,0,3,False)
# (Mayor,1,2,presionarterialnivel2,alto,0,0,1,1,0,3,False)
# (Mayor,1,1,presionarterialnivel2,muyalto,0,2,0,2,0,7,True)
# (Mayor,1,2,elevada,alto,1,0,0,1,0,3,False)
# (Mayor,1,3,elevada,muyalto,0,0,1,2,0,7,True)
# (Mayor,1,3,normal,alto,0,2,1,2,0,7,False)
# (Joven,1,3,normal,muyalto,0,0,0,1,0,3,True)
# (Mayor,1,4,presionarterialnivel2,muyalto,1,2,0,2,3,7,True)
# (Joven,1,3,normal,muyalto,0,0,0,1,0,3,False)
# (Joven,1,2,elevada,muyalto,0,2,0,1,0,3,False)
# (Mayor,0,3,normal,muyalto,0,0,0,1,1,3,False)
# (Mayor,1,1,presionarterialnivel2,muyalto,1,0,0,2,0,7,False)
# (Joven,0,4,normal,muyalto,0,2,0,2,0,3,False)
# (Mayor,0,3,normal,muyalto,0,2,0,2,0,7,False)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,1,2,1,7,True)
# (Mayor,1,4,elevada,muyalto,0,2,1,3,1,3,True)
# (Mayor,1,4,presionarterialnivel1,muyalto,0,2,0,2,3,3,True)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,0,1,1,0,7,True)
# (Mayor,1,4,elevada,muyalto,0,2,0,1,2,7,True)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,2,0,2,2,7,True)
# (Mayor,1,3,normal,muyalto,0,0,0,1,1,7,False)
# (Joven,1,2,normal,normal,1,0,0,1,0,7,False)
# (Mayor,1,4,elevada,muyalto,0,2,1,1,3,3,True)
# (Mayor,0,3,normal,alto,0,0,0,2,0,3,False)
# (Mayor,0,4,normal,muyalto,0,2,0,2,0,3,False)
# (Joven,1,3,elevada,muyalto,1,0,0,1,2,3,False)
# (Mayor,1,4,presionarterialnivel1,alto,0,0,1,1,0,7,False)
# (Mayor,0,2,presionarterialnivel1,muyalto,1,2,1,1,1,3,False)
# (Joven,1,4,elevada,muyalto,0,2,1,1,0,7,True)
# (Joven,0,2,normal,normal,0,0,0,2,0,3,False)
# (Mayor,1,3,presionarterialnivel2,muyalto,0,0,1,2,1,7,True)
# (Mayor,1,4,presionarterialnivel2,alto,0,2,1,1,0,7,False)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,0,1,2,0,3,True)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,2,0,2,0,3,False)
# (Mayor,1,4,presionarterialnivel2,alto,0,2,0,2,2,6,True)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,0,1,2,1,7,True)
# (Mayor,1,4,normal,alto,1,0,0,1,3,7,False)
# (Mayor,1,4,presionarterialnivel1,normal,0,2,1,2,1,6,True)
# (Joven,1,3,presionarterialnivel1,muyalto,0,0,0,1,1,3,False)
# (Mayor,1,3,presionarterialnivel1,muyalto,1,2,0,1,3,3,False)
# (Joven,1,4,elevada,muyalto,0,2,0,2,0,7,True)
# (Mayor,0,4,presionarterialnivel1,muyalto,0,2,1,2,2,7,True)
# (Joven,1,1,presionarterialnivel2,muyalto,0,2,0,1,2,3,False)
# (Mayor,1,1,presionarterialnivel2,muyalto,0,2,0,3,0,7,False)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,2,0,1,0,3,True)
# (Mayor,0,2,presionarterialnivel2,normal,0,0,0,1,2,3,False)
# (Joven,1,3,elevada,alto,1,0,0,3,0,7,False)
# (Mayor,1,2,presionarterialnivel2,muyalto,0,0,1,2,3,6,True)
# (Mayor,1,2,crisis,muyalto,0,2,0,1,1,7,True)
# (Mayor,1,3,presionarterialnivel2,muyalto,0,2,0,2,3,7,True)
# (Joven,1,3,elevada,normal,0,0,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel2,muyalto,0,0,1,2,3,7,True)
# (Mayor,0,4,presionarterialnivel1,muyalto,1,0,0,2,3,3,True)
# (Mayor,0,3,elevada,alto,0,2,0,2,0,3,False)
# (Mayor,1,4,normal,muyalto,0,2,1,2,2,3,True)
# (Mayor,1,1,presionarterialnivel2,alto,1,2,0,2,1,3,False)
# (Joven,0,4,presionarterialnivel1,alto,0,2,1,2,0,3,False)
# (Joven,0,2,elevada,muyalto,0,0,0,1,0,3,False)
# (Mayor,1,1,presionarterialnivel2,muyalto,0,2,0,1,0,3,True)
# (Joven,0,4,normal,muyalto,0,2,0,1,0,3,False)
# (Mayor,0,4,crisis,muyalto,0,0,1,1,0,3,False)
# (Mayor,1,3,presionarterialnivel2,normal,1,0,0,1,1,7,False)
# (Mayor,0,3,presionarterialnivel2,muyalto,0,0,0,1,0,7,False)
# (Joven,1,4,normal,alto,0,0,0,1,0,7,False)
# (Joven,1,4,presionarterialnivel2,muyalto,0,2,1,2,3,7,True)
# (Mayor,1,4,elevada,muyalto,0,2,1,2,2,7,True)
# (Joven,1,4,presionarterialnivel2,normal,0,2,1,2,0,7,True)
# (Mayor,1,2,presionarterialnivel1,muyalto,0,0,0,1,0,3,False)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,0,1,2,0,3,True)
# (Joven,0,3,elevada,alto,0,0,0,1,0,3,False)
# (Joven,1,1,elevada,alto,0,0,1,2,0,7,True)
# (Joven,1,3,presionarterialnivel1,alto,0,2,0,2,0,3,False)
# (Mayor,0,4,presionarterialnivel2,alto,1,0,1,2,2,7,True)
# (Mayor,1,4,normal,alto,0,0,0,1,1,3,True)
# (Mayor,1,1,elevada,normal,0,2,0,2,0,7,False)
# (Joven,0,2,normal,alto,0,0,0,1,0,3,False)
# (Joven,0,4,presionarterialnivel1,muyalto,0,2,1,2,0,3,False)
# (Mayor,0,4,presionarterialnivel1,muyalto,0,0,0,2,2,3,False)
# (Mayor,1,4,presionarterialnivel1,muyalto,0,2,0,1,0,3,False)
# (Joven,0,3,normal,muyalto,0,2,1,1,0,3,False)
# (Mayor,0,3,normal,muyalto,0,2,0,1,0,3,False)
# (Joven,0,3,normal,normal,0,0,0,1,0,3,False)
# (Mayor,1,4,elevada,muyalto,0,0,1,2,2,7,True)
# (Mayor,0,4,normal,muyalto,0,0,1,2,2,3,True)
# (Joven,0,2,normal,alto,0,0,0,1,0,3,False)
# (Joven,1,4,normal,alto,0,0,0,1,0,3,False)
# (Mayor,0,3,presionarterialnivel2,muyalto,0,0,0,1,1,3,False)
# (Mayor,1,4,normal,alto,0,2,1,2,1,3,True)
# (Mayor,1,4,normal,alto,0,2,1,1,1,3,True)
# (Mayor,0,3,presionarterialnivel1,normal,0,2,0,2,0,3,False)
# (Mayor,0,4,crisis,muyalto,0,1,1,2,0,3,True)
# (Joven,1,3,normal,normal,0,2,0,1,3,3,True)
# (Mayor,0,2,elevada,muyalto,0,2,1,1,1,3,False)
# (Mayor,0,3,presionarterialnivel2,alto,0,0,0,1,1,3,False)
# (Mayor,1,4,elevada,muyalto,0,2,1,2,2,3,True)
# (Mayor,1,4,presionarterialnivel1,muyalto,1,2,1,3,0,7,True)
# (Joven,1,4,elevada,muyalto,0,2,0,1,0,7,True)
# (Joven,0,2,presionarterialnivel1,muyalto,0,0,0,2,0,3,False)
# (Joven,1,2,elevada,muyalto,0,0,0,1,0,3,False)
# (Joven,1,2,normal,alto,0,0,0,1,0,3,False)
# (Joven,0,2,elevada,muyalto,0,0,0,1,0,3,False)
# (Joven,0,4,presionarterialnivel1,muyalto,0,0,0,1,0,3,False)
# (Mayor,1,1,presionarterialnivel1,alto,0,0,0,2,2,3,True)
# (Mayor,0,3,elevada,normal,1,0,0,1,0,3,False)
# (Mayor,1,4,elevada,alto,0,0,0,2,0,3,True)
# (Mayor,1,4,normal,alto,0,0,0,1,1,7,True)
# (Joven,1,4,normal,muyalto,0,2,1,2,1,3,True)
# (Mayor,1,4,elevada,alto,0,0,0,1,2,7,True)
# (Mayor,1,2,elevada,alto,1,2,0,1,0,3,False)
# (Mayor,1,4,normal,alto,0,0,1,2,0,6,False)
# (Mayor,1,4,presionarterialnivel2,alto,0,0,0,2,1,7,True)
# (Mayor,1,4,elevada,muyalto,0,0,1,2,1,7,False)
# (Mayor,0,3,elevada,muyalto,0,2,0,1,0,3,False)
# (Joven,1,4,normal,muyalto,0,0,0,2,0,3,False)
# (Joven,0,3,elevada,alto,0,0,0,2,0,3,False)
# (Mayor,0,4,normal,alto,0,0,0,1,2,3,False)
# (Mayor,0,3,presionarterialnivel2,normal,0,1,0,2,0,3,False)
# (Mayor,1,2,presionarterialnivel2,muyalto,0,2,0,1,0,3,False)
# (Mayor,1,2,elevada,muyalto,0,0,0,1,0,7,True)
# (Joven,0,3,normal,muyalto,0,0,0,2,1,3,False)
# (Mayor,0,2,presionarterialnivel1,muyalto,1,2,0,1,2,3,True)
# (Mayor,0,1,presionarterialnivel2,alto,0,0,0,1,0,3,False)
# (Joven,1,3,elevada,alto,0,0,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel1,normal,0,2,1,2,1,3,True)
# (Joven,1,4,presionarterialnivel1,muyalto,0,0,1,2,0,6,True)
# (Mayor,1,3,elevada,alto,1,0,0,2,1,6,True)
# (Joven,1,4,presionarterialnivel2,alto,0,0,0,1,0,7,True)
# (Joven,1,3,presionarterialnivel1,normal,0,0,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel2,alto,0,2,1,1,1,7,True)
# (Mayor,1,4,presionarterialnivel2,alto,0,2,0,1,0,6,False)
# (Joven,1,4,presionarterialnivel2,muyalto,0,0,1,2,2,7,True)
# (Mayor,0,4,normal,normal,0,0,0,2,0,3,False)
# (Mayor,1,1,presionarterialnivel1,alto,0,0,0,1,2,3,True)
# (Mayor,1,1,presionarterialnivel2,alto,0,2,0,2,0,7,False)
# (Mayor,0,3,presionarterialnivel2,muyalto,0,2,0,2,1,3,False)
# (Joven,0,3,presionarterialnivel1,alto,0,0,0,2,0,3,False)
# (Mayor,1,2,presionarterialnivel2,alto,0,2,0,1,1,3,True)
# (Mayor,0,4,presionarterialnivel1,normal,0,0,0,2,0,3,False)
# (Mayor,1,4,normal,muyalto,0,0,1,2,1,7,True)
# (Joven,1,3,presionarterialnivel1,muyalto,0,0,0,1,0,3,False)
# (Mayor,0,4,elevada,alto,0,1,1,2,1,7,True)
# (Joven,1,2,elevada,normal,0,0,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel2,alto,0,0,0,1,1,7,True)
# (Mayor,1,4,normal,muyalto,0,1,0,3,3,6,True)
# (Mayor,0,4,presionarterialnivel2,alto,1,2,1,2,2,6,True)
# (Mayor,1,2,presionarterialnivel1,alto,0,2,0,1,0,7,False)
# (Mayor,1,2,elevada,alto,0,0,0,3,0,3,False)
# (Mayor,1,3,presionarterialnivel2,alto,0,2,0,2,0,7,True)
# (Mayor,0,2,presionarterialnivel1,muyalto,0,0,0,1,0,3,False)
# (Joven,1,4,elevada,normal,0,0,1,3,0,6,True)
# (Mayor,1,4,presionarterialnivel2,normal,0,2,1,1,2,7,True)
# (Mayor,0,4,elevada,normal,0,0,1,2,0,3,True)
# (Joven,1,2,elevada,normal,0,0,0,1,0,3,False)
# (Mayor,1,4,presionarterialnivel2,normal,1,2,0,2,2,6,True)
# (Mayor,0,4,presionarterialnivel2,muyalto,0,0,1,2,0,7,True)
# (Joven,1,1,normal,muyalto,0,0,0,2,0,7,True)
# (Mayor,1,4,presionarterialnivel2,normal,1,0,0,2,2,7,True)
# (Mayor,1,4,presionarterialnivel1,normal,0,0,1,2,1,7,True)
# (Mayor,0,2,presionarterialnivel1,alto,0,2,0,2,1,3,True)
# 297

# %%
#Guardar el script
with open("C:/Users/dafef/OneDrive - Universidad de los Andes/Decimo Semestre/Analitica computacional/Proyecto 2 Enfermedades cardiacas/datacardiaca4.sql", "w")as sql_file:
    sql_file.write(sql_script)

# %%
import psycopg2
engine = psycopg2.connect(
    dbname="danielchrister",
    user="danielchrister",
    password="danielactd",
    host="danielchrister.cpucxidqdwyr.us-east-1.rds.amazonaws.com",
    port='5432'
)

# %%
cursor = engine.cursor()

# %%
query = """
SELECT * 
FROM pg_catalog.pg_tables 
WHERE schemaname='public';"""
cursor.execute(query)
result = cursor.fetchall()
result
# Out:
# []
